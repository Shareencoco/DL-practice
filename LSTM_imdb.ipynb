# %% [markdown]
# <a href="https://colab.research.google.com/github/Shareencoco/DL-practice/blob/main/LSTM_imdb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.datasets import imdb

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,LSTM,Dropout,Dense

# %%
#LOAD DATA
(X_train,y_train),(X_test,y_test) = imdb.load_data(num_words=10000)

# %%
#PREPROCESS
from tensorflow.keras.preprocessing.sequence import pad_sequences
X_train = pad_sequences(X_train,maxlen=200)
X_test = pad_sequences(X_test,maxlen=200)

# from sklearn.preprocessing import LabelEncoder
# le=LabelEncoder()
# y_train = le.fit_transform(y_train)
# y_test = le.transform(y_test)

# %%
#BUILD MODEL
model = Sequential([
    Embedding(10000,128),
    LSTM(64),
    Dropout(0.3),
    Dense(1,activation='sigmoid')
])

# %%
#COMPILE
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

#TRAIN
history=model.fit(X_train,y_train,
          validation_data=(X_test,y_test),
          epochs=5,
          batch_size=64,
          verbose=1
          )
# Out:
# Epoch 1/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.8469 - loss: 0.3694 - val_accuracy: 0.8602 - val_loss: 0.3400
# Epoch 2/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9082 - loss: 0.2374 - val_accuracy: 0.8387 - val_loss: 0.3731
# Epoch 3/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9316 - loss: 0.1859 - val_accuracy: 0.8706 - val_loss: 0.3244
# Epoch 4/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9510 - loss: 0.1330 - val_accuracy: 0.8659 - val_loss: 0.3963
# Epoch 5/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9604 - loss: 0.1133 - val_accuracy: 0.8542 - val_loss: 0.3978

# %%
#VISUALIZE
#EVALUATE

# %%
#PREDICT 1 INSTANCE
sample=X_test[0].reshape(1,200)
predicted=model.predict(sample)
# print(X_test[0])
print("Predicted Class:","Positive" if predicted>0.5 else "Negative")
print("Actual class:","Positive" if predicted>0.5 else "Negative")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predicted Class: Negative
# Actual class: Negative
